# %%
#Descargamos el dataset

from datasets import load_dataset

dataset = load_dataset("FJC/corpusELE.csv")
dataset
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'numero', 'nivel', 'lenguaM', 'pClave', 'frase', 'archivo'],
#         num_rows: 46787
#     })
# })

# %%
#Observamos las categorías:

LABELS = dataset['train'].unique('nivel')
NUM_LABELS = len(LABELS)
print('LABELS:', LABELS, 'num_labels:', NUM_LABELS )
# Out:
# LABELS: ['A1', 'B2', 'A2', 'B1', 'C1'] num_labels: 5

# %%
#Contamos cuántos ejemplos hay de cada categoría

class_counts = dataset['train'].to_pandas()['nivel'].value_counts()
print(class_counts)
# Out:
# nivel
# A2    13926
# A1    12284
# B1    10848
# B2     6601
# C1     3128
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from google.colab import drive
import pandas as pd

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Mantenemos las columnas de 'nivel' y 'frase'
df_processed = df_processed[['nivel', 'frase']].copy()

# Las renombramos con 'label' y 'text'
df_processed = df_processed.rename(columns={'nivel': 'label', 'frase': 'text'})

# Creamos la columna de 'id'
df_processed['id'] = range(len(df_processed))

# %%
# Vemos el dataset generado:
display(df_processed.head())
# Out:
#   label                                               text  id
# 0    A1  mi familia es solo 3 persona , me madre y me h...   0
# 1    B2  La cuestión es que la propia temática ya nos o...   1
# 2    A2  Nos ibe muchas luegos como museos , restaurant...   2
# 3    A1              Entoncés , se puede que llego tarde .   3
# 4    A1  A mi me gusta el ballet clásico , escuchar mús...   4

# %%
# Reordenamos las columnas 'id', 'text', 'label'
df_processed = df_processed[['id', 'text', 'label']]

# Confirmamos nuestro dataset
display(df_processed.head())
# Out:
#    id                                               text label
# 0   0  mi familia es solo 3 persona , me madre y me h...    A1
# 1   1  La cuestión es que la propia temática ya nos o...    B2
# 2   2  Nos ibe muchas luegos como museos , restaurant...    A2
# 3   3              Entoncés , se puede que llego tarde .    A1
# 4   4  A mi me gusta el ballet clásico , escuchar mús...    A1

# %%
df_processed = dataset['train'].to_pandas()


# Separamos los conjuntos de train y validation
train_size = 42108
val_size = 4679

total_samples = len(df_processed)
test_proportion = val_size / total_samples

train_df, val_df = train_test_split(df_processed, test_size=test_proportion, random_state=42)

# Define the path to save the files in Google Drive
save_path = '/content/drive/MyDrive/corpusELE_data/'

# Create the directory if it doesn't exist
import os
os.makedirs(save_path, exist_ok=True)

# Save the training and validation sets as CSV files
train_df.to_csv(os.path.join(save_path, 'train_corpusELE.csv'), index=False)
val_df.to_csv(os.path.join(save_path, 'val_corpusELE.csv'), index=False)

print(f"Training set saved to: {os.path.join(save_path, 'train_corpusELE.csv')}")
print(f"Validation set saved to: {os.path.join(save_path, 'val_corpusELE.csv')}")

print(f"Training set shape: {train_df.shape}")
print(f"Validation set shape: {val_df.shape}")
# Out:
# Training set saved to: /content/drive/MyDrive/corpusELE_data/train_corpusELE.csv
# Validation set saved to: /content/drive/MyDrive/corpusELE_data/val_corpusELE.csv
# Training set shape: (42108, 3)
# Validation set shape: (4679, 3)
